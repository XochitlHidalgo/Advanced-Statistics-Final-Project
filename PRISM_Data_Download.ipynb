# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import datetime as dt
import requests
import zipfile
import os
import time

# %% [markdown]
# ## Read in file containing storm information (Name, Dates, Category)

# %%
hur_dat = pd.read_csv('Hurricanes.csv', skiprows=1)
hur_dat = hur_dat.rename(columns={'Unnamed: 0':'Name','Unnamed: 1':'start','Unnamed: 2':'end','Unnamed: 3':'Category'}).dropna(how='all')
hur_dat['start'] = pd.to_datetime(hur_dat['start'])
hur_dat['end'] = pd.to_datetime(hur_dat['end'])
hur_dat
# Out:
# /var/folders/z6/1637m0dd1p1dn2n4wrbvj6kw0000gn/T/ipykernel_91402/4286610772.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   hur_dat['start'] = pd.to_datetime(hur_dat['start'])
# /var/folders/z6/1637m0dd1p1dn2n4wrbvj6kw0000gn/T/ipykernel_91402/4286610772.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   hur_dat['end'] = pd.to_datetime(hur_dat['end'])
#          Name      start        end  Category  Unnamed: 4  Unnamed: 5  \
# 0      Milton 2024-10-09 2024-10-10       2.0         NaN         NaN
# 1      Helene 2024-09-26 2024-09-28       4.0         NaN         NaN
# 2    Francine 2024-09-10 2024-09-12       2.0         NaN         NaN
# 3       Debby 2024-08-04 2024-08-08       1.0         NaN         NaN
# 4       Beryl 2024-07-08 2024-07-09       1.0         NaN         NaN
# 5      Idalia 2023-08-30 2023-08-31       3.0         NaN         NaN
# 6      Nicole 2022-11-09 2022-11-11       1.0         NaN         NaN
# 7         Ian 2022-09-27 2022-09-30       4.0         NaN         NaN
# 8    Nicholas 2021-09-13 2021-09-16       1.0         NaN         NaN
# 9         Ida 2021-08-28 2021-09-01       4.0         NaN         NaN
# 10       Zeta 2020-10-28 2020-10-29       3.0         NaN         NaN
# 11      Delta 2020-10-09 2020-10-10       2.0         NaN         NaN
# 12      Sally 2020-09-12 2020-09-17       2.0         NaN         NaN
# 13      Laura 2020-08-25 2020-08-29       4.0         NaN         NaN
# 14     Isaias 2020-08-01 2020-08-04       1.0         NaN         NaN
# 15      Hanna 2020-07-25 2020-07-26       1.0         NaN         NaN
# 16     Dorian 2019-09-02 2019-09-07       2.0         NaN         NaN
# 17      Barry 2019-07-11 2019-07-16       1.0         NaN         NaN
# 18    Michael 2018-10-09 2018-10-11       5.0         NaN         NaN
# 19   Florence 2018-09-13 2018-09-17       1.0         NaN         NaN
# 20       Nate 2017-10-07 2017-10-08       1.0         NaN         NaN
# 21       Irma 2017-09-09 2017-09-13       4.0         NaN         NaN
# 22     Harvey 2017-08-25 2017-09-01       4.0         NaN         NaN
# 23    Matthew 2016-10-06 2016-10-09       2.0         NaN         NaN
# 24    Hermine 2016-08-30 2016-09-03       1.0         NaN         NaN
# 25     Arthur 2014-06-29 2014-07-05       2.0         NaN         NaN
# 26      Isaac 2012-08-26 2012-09-01       1.0         NaN         NaN
# 27      Irene 2011-08-25 2011-08-28       1.0         NaN         NaN
# 28        Ike 2008-09-09 2008-09-14       2.0         NaN         NaN
# 29     Gustav 2008-08-30 2008-09-04       2.0         NaN         NaN
# 30      Dolly 2008-07-23 2008-07-26       1.0         NaN         NaN
# 31   Humberto 2007-09-12 2007-09-14       1.0         NaN         NaN
# 32      Wilma 2005-10-24 2005-10-25       3.0         NaN         NaN
# 33       Rita 2005-09-20 2005-09-26       3.0         NaN         NaN
# 34    Katrina 2005-08-25 2005-08-30       3.0         NaN         NaN
# 35     Dennis 2005-07-08 2005-07-13       3.0         NaN         NaN
# 36      Cindy 2005-07-05 2005-07-07       1.0         NaN         NaN
# 37     Jeanne 2004-09-25 2004-09-28       3.0         NaN         NaN
# 38       Ivan 2004-09-16 2004-09-18       3.0         NaN         NaN
# 39     Gaston 2004-08-28 2004-08-31       1.0         NaN         NaN
# 40    Frances 2004-09-04 2004-09-08       2.0         NaN         NaN
# 41    Charley 2004-08-13 2004-08-14       4.0         NaN         NaN
# 42     Isabel 2003-09-18 2003-09-19       2.0         NaN         NaN
# 43  Claudette 2003-07-15 2003-07-17       1.0         NaN         NaN
# 44       Lili 2002-10-02 2002-10-04       1.0         NaN         NaN
# 45      Floyd 1999-09-14 1999-09-17       2.0         NaN         NaN
# 46       Bret 1999-08-22 1999-08-24       3.0         NaN         NaN
# 47    Georges 1998-09-25 1998-10-01       2.0         NaN         NaN
# 48       Earl 1998-09-02 1998-09-03       1.0         NaN         NaN
# 49     Bonnie 1998-08-26 1998-08-29       2.0         NaN         NaN
# 50      Danny 1997-07-17 1997-07-26       1.0         NaN         NaN
# 51       Fran 1996-09-05 1996-09-08       3.0         NaN         NaN
# 52     Bertha 1996-07-11 1996-07-14       2.0         NaN         NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# 23         NaN         NaN         NaN
# 24         NaN         NaN         NaN
# 25         NaN         NaN         NaN
# 26         NaN         NaN         NaN
# 27         NaN         NaN         NaN
# 28         NaN         NaN         NaN
# 29         NaN         NaN         NaN
# 30         NaN         NaN         NaN
# 31         NaN         NaN         NaN
# 32         NaN         NaN         NaN
# 33         NaN         NaN         NaN
# 34         NaN         NaN         NaN
# 35         NaN         NaN         NaN
# 36         NaN         NaN         NaN
# 37         NaN         NaN         NaN
# 38         NaN         NaN         NaN
# 39         NaN         NaN         NaN
# 40         NaN         NaN         NaN
# 41         NaN         NaN         NaN
# 42         NaN         NaN         NaN
# 43         NaN         NaN         NaN
# 44         NaN         NaN         NaN
# 45         NaN         NaN         NaN
# 46         NaN         NaN         NaN
# 47         NaN         NaN         NaN
# 48         NaN         NaN         NaN
# 49         NaN         NaN         NaN
# 50         NaN         NaN         NaN
# 51         NaN         NaN         NaN
# 52         NaN         NaN         NaN

# %% [markdown]
# ## For each storm, request files from website for all dates in csv and extract necessary nc file.

# %%
for i in range(len(hur_dat)):
    storm = hur_dat['Name'][i]
    base_url = "https://services.nacse.org/prism/data/get/us/4km/ppt"

    start = hur_dat['start'][i]
    stop = hur_dat['end'][i]

    current = start
    while current <= stop:
        day = current.strftime("%Y%m%d")
        url = f"{base_url}/{day}?format=nc"

        print(f"Downloading {url}")

        response = requests.get(url, stream=True)
        response.raise_for_status()

        # Temporary ZIP filename
        zip_filename = f"tmp_{day}.zip"
        with open(zip_filename, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)

        # Extract only the .nc file
        with zipfile.ZipFile(zip_filename, 'r') as z:
            for member in z.namelist():
                if member.endswith(".nc"):
                    # Save extracted nc with storm name
                    outname = f"{storm}_{day}.nc"
                    z.extract(member)
                    os.rename(member, outname)
                    print(f"Saved {outname}")

        # Remove ZIP
        os.remove(zip_filename)

        time.sleep(2)
        current += dt.timedelta(days=1)
# Out:
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20241009?format=nc
# Saved Milton_20241009.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20241010?format=nc
# Saved Milton_20241010.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240926?format=nc
# Saved Helene_20240926.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240927?format=nc
# Saved Helene_20240927.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240928?format=nc
# Saved Helene_20240928.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240910?format=nc
# Saved Francine_20240910.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240911?format=nc
# Saved Francine_20240911.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240912?format=nc
# Saved Francine_20240912.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240804?format=nc
# Saved Debby_20240804.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240805?format=nc
# Saved Debby_20240805.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240806?format=nc
# Saved Debby_20240806.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240807?format=nc
# Saved Debby_20240807.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240808?format=nc
# Saved Debby_20240808.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240708?format=nc
# Saved Beryl_20240708.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20240709?format=nc
# Saved Beryl_20240709.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20230830?format=nc
# Saved Idalia_20230830.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20230831?format=nc
# Saved Idalia_20230831.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20221109?format=nc
# Saved Nicole_20221109.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20221110?format=nc
# Saved Nicole_20221110.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20221111?format=nc
# Saved Nicole_20221111.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20220927?format=nc
# Saved Ian_20220927.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20220928?format=nc
# Saved Ian_20220928.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20220929?format=nc
# Saved Ian_20220929.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20220930?format=nc
# Saved Ian_20220930.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210913?format=nc
# Saved Nicholas_20210913.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210914?format=nc
# Saved Nicholas_20210914.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210915?format=nc
# Saved Nicholas_20210915.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210916?format=nc
# Saved Nicholas_20210916.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210828?format=nc
# Saved Ida_20210828.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210829?format=nc
# Saved Ida_20210829.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210830?format=nc
# Saved Ida_20210830.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210831?format=nc
# Saved Ida_20210831.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20210901?format=nc
# Saved Ida_20210901.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20201028?format=nc
# Saved Zeta_20201028.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20201029?format=nc
# Saved Zeta_20201029.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20201009?format=nc
# Saved Delta_20201009.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20201010?format=nc
# Saved Delta_20201010.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200912?format=nc
# Saved Sally_20200912.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200913?format=nc
# Saved Sally_20200913.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200914?format=nc
# Saved Sally_20200914.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200915?format=nc
# Saved Sally_20200915.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200916?format=nc
# Saved Sally_20200916.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200917?format=nc
# Saved Sally_20200917.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200825?format=nc
# Saved Laura_20200825.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200826?format=nc
# Saved Laura_20200826.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200827?format=nc
# Saved Laura_20200827.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200828?format=nc
# Saved Laura_20200828.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200829?format=nc
# Saved Laura_20200829.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200801?format=nc
# Saved Isaias_20200801.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200802?format=nc
# Saved Isaias_20200802.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200803?format=nc
# Saved Isaias_20200803.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200804?format=nc
# Saved Isaias_20200804.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200725?format=nc
# Saved Hanna_20200725.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20200726?format=nc
# Saved Hanna_20200726.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190902?format=nc
# Saved Dorian_20190902.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190903?format=nc
# Saved Dorian_20190903.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190904?format=nc
# Saved Dorian_20190904.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190905?format=nc
# Saved Dorian_20190905.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190906?format=nc
# Saved Dorian_20190906.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190907?format=nc
# Saved Dorian_20190907.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190711?format=nc
# Saved Barry_20190711.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190712?format=nc
# Saved Barry_20190712.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190713?format=nc
# Saved Barry_20190713.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190714?format=nc
# Saved Barry_20190714.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190715?format=nc
# Saved Barry_20190715.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20190716?format=nc
# Saved Barry_20190716.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20181009?format=nc
# Saved Michael_20181009.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20181010?format=nc
# Saved Michael_20181010.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20181011?format=nc
# Saved Michael_20181011.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20180913?format=nc
# Saved Florence_20180913.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20180914?format=nc
# Saved Florence_20180914.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20180915?format=nc
# Saved Florence_20180915.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20180916?format=nc
# Saved Florence_20180916.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20180917?format=nc
# Saved Florence_20180917.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20171007?format=nc
# Saved Nate_20171007.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20171008?format=nc
# Saved Nate_20171008.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170909?format=nc
# Saved Irma_20170909.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170910?format=nc
# Saved Irma_20170910.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170911?format=nc
# Saved Irma_20170911.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170912?format=nc
# Saved Irma_20170912.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170913?format=nc
# Saved Irma_20170913.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170825?format=nc
# Saved Harvey_20170825.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170826?format=nc
# Saved Harvey_20170826.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170827?format=nc
# Saved Harvey_20170827.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170828?format=nc
# Saved Harvey_20170828.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170829?format=nc
# Saved Harvey_20170829.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170830?format=nc
# Saved Harvey_20170830.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170831?format=nc
# Saved Harvey_20170831.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20170901?format=nc
# Saved Harvey_20170901.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20161006?format=nc
# Saved Matthew_20161006.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20161007?format=nc
# Saved Matthew_20161007.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20161008?format=nc
# Saved Matthew_20161008.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20161009?format=nc
# Saved Matthew_20161009.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20160830?format=nc
# Saved Hermine_20160830.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20160831?format=nc
# Saved Hermine_20160831.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20160901?format=nc
# Saved Hermine_20160901.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20160902?format=nc
# Saved Hermine_20160902.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20160903?format=nc
# Saved Hermine_20160903.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20140629?format=nc
# Saved Arthur_20140629.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20140630?format=nc
# Saved Arthur_20140630.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20140701?format=nc
# Saved Arthur_20140701.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20140702?format=nc
# Saved Arthur_20140702.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20140703?format=nc
# Saved Arthur_20140703.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20140704?format=nc
# Saved Arthur_20140704.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20140705?format=nc
# Saved Arthur_20140705.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20120826?format=nc
# Saved Isaac_20120826.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20120827?format=nc
# Saved Isaac_20120827.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20120828?format=nc
# Saved Isaac_20120828.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20120829?format=nc
# Saved Isaac_20120829.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20120830?format=nc
# Saved Isaac_20120830.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20120831?format=nc
# Saved Isaac_20120831.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20120901?format=nc
# Saved Isaac_20120901.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20110825?format=nc
# Saved Irene_20110825.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20110826?format=nc
# Saved Irene_20110826.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20110827?format=nc
# Saved Irene_20110827.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20110828?format=nc
# Saved Irene_20110828.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080909?format=nc
# Saved Ike_20080909.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080910?format=nc
# Saved Ike_20080910.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080911?format=nc
# Saved Ike_20080911.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080912?format=nc
# Saved Ike_20080912.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080913?format=nc
# Saved Ike_20080913.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080914?format=nc
# Saved Ike_20080914.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080830?format=nc
# Saved Gustav_20080830.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080831?format=nc
# Saved Gustav_20080831.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080901?format=nc
# Saved Gustav_20080901.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080902?format=nc
# Saved Gustav_20080902.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080903?format=nc
# Saved Gustav_20080903.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080904?format=nc
# Saved Gustav_20080904.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080723?format=nc
# Saved Dolly_20080723.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080724?format=nc
# Saved Dolly_20080724.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080725?format=nc
# Saved Dolly_20080725.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20080726?format=nc
# Saved Dolly_20080726.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20070912?format=nc
# Saved Humberto_20070912.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20070913?format=nc
# Saved Humberto_20070913.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20070914?format=nc
# Saved Humberto_20070914.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20051024?format=nc
# Saved Wilma_20051024.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20051025?format=nc
# Saved Wilma_20051025.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050920?format=nc
# Saved Rita_20050920.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050921?format=nc
# Saved Rita_20050921.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050922?format=nc
# Saved Rita_20050922.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050923?format=nc
# Saved Rita_20050923.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050924?format=nc
# Saved Rita_20050924.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050925?format=nc
# Saved Rita_20050925.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050926?format=nc
# Saved Rita_20050926.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050825?format=nc
# Saved Katrina_20050825.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050826?format=nc
# Saved Katrina_20050826.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050827?format=nc
# Saved Katrina_20050827.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050828?format=nc
# Saved Katrina_20050828.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050829?format=nc
# Saved Katrina_20050829.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050830?format=nc
# Saved Katrina_20050830.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050708?format=nc
# Saved Dennis_20050708.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050709?format=nc
# Saved Dennis_20050709.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050710?format=nc
# Saved Dennis_20050710.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050711?format=nc
# Saved Dennis_20050711.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050712?format=nc
# Saved Dennis_20050712.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050713?format=nc
# Saved Dennis_20050713.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050705?format=nc
# Saved Cindy_20050705.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050706?format=nc
# Saved Cindy_20050706.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20050707?format=nc
# Saved Cindy_20050707.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040925?format=nc
# Saved Jeanne_20040925.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040926?format=nc
# Saved Jeanne_20040926.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040927?format=nc
# Saved Jeanne_20040927.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040928?format=nc
# Saved Jeanne_20040928.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040916?format=nc
# Saved Ivan_20040916.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040917?format=nc
# Saved Ivan_20040917.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040918?format=nc
# Saved Ivan_20040918.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040828?format=nc
# Saved Gaston_20040828.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040829?format=nc
# Saved Gaston_20040829.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040830?format=nc
# Saved Gaston_20040830.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040831?format=nc
# Saved Gaston_20040831.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040904?format=nc
# Saved Frances_20040904.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040905?format=nc
# Saved Frances_20040905.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040906?format=nc
# Saved Frances_20040906.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040907?format=nc
# Saved Frances_20040907.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040908?format=nc
# Saved Frances_20040908.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040813?format=nc
# Saved Charley_20040813.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20040814?format=nc
# Saved Charley_20040814.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20030918?format=nc
# Saved Isabel_20030918.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20030919?format=nc
# Saved Isabel_20030919.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20030715?format=nc
# Saved Claudette_20030715.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20030716?format=nc
# Saved Claudette_20030716.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20030717?format=nc
# Saved Claudette_20030717.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20021002?format=nc
# Saved Lili_20021002.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20021003?format=nc
# Saved Lili_20021003.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/20021004?format=nc
# Saved Lili_20021004.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19990914?format=nc
# Saved Floyd_19990914.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19990915?format=nc
# Saved Floyd_19990915.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19990916?format=nc
# Saved Floyd_19990916.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19990917?format=nc
# Saved Floyd_19990917.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19990822?format=nc
# Saved Bret_19990822.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19990823?format=nc
# Saved Bret_19990823.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19990824?format=nc
# Saved Bret_19990824.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980925?format=nc
# Saved Georges_19980925.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980926?format=nc
# Saved Georges_19980926.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980927?format=nc
# Saved Georges_19980927.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980928?format=nc
# Saved Georges_19980928.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980929?format=nc
# Saved Georges_19980929.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980930?format=nc
# Saved Georges_19980930.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19981001?format=nc
# Saved Georges_19981001.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980902?format=nc
# Saved Earl_19980902.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980903?format=nc
# Saved Earl_19980903.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980826?format=nc
# Saved Bonnie_19980826.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980827?format=nc
# Saved Bonnie_19980827.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980828?format=nc
# Saved Bonnie_19980828.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19980829?format=nc
# Saved Bonnie_19980829.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970717?format=nc
# Saved Danny_19970717.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970718?format=nc
# Saved Danny_19970718.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970719?format=nc
# Saved Danny_19970719.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970720?format=nc
# Saved Danny_19970720.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970721?format=nc
# Saved Danny_19970721.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970722?format=nc
# Saved Danny_19970722.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970723?format=nc
# Saved Danny_19970723.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970724?format=nc
# Saved Danny_19970724.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970725?format=nc
# Saved Danny_19970725.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19970726?format=nc
# Saved Danny_19970726.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19960905?format=nc
# Saved Fran_19960905.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19960906?format=nc
# Saved Fran_19960906.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19960907?format=nc
# Saved Fran_19960907.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19960908?format=nc
# Saved Fran_19960908.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19960711?format=nc
# Saved Bertha_19960711.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19960712?format=nc
# Saved Bertha_19960712.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19960713?format=nc
# Saved Bertha_19960713.nc
# Downloading https://services.nacse.org/prism/data/get/us/4km/ppt/19960714?format=nc
# Saved Bertha_19960714.nc
